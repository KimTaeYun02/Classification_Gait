# %% [markdown]
# ### import

# %%
import module.feature_extract as feature
import os
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### videos to keypoint

# %%
ABNORMAL_PATH = os.listdir("videos/abnormal_gait/")
NORMAL_PATH = os.listdir("videos/normal_gait/")

# %%
#abnormal
for path in ABNORMAL_PATH:       
    i = 0
    VIDEO_PATH = "videos/abnormal_gait/" + path +"/" 
    for video_file in os.listdir(VIDEO_PATH):
        dataframe = feature.extract_keypoint(path = VIDEO_PATH + video_file, 
                                        save_path = "dataset/"+ path + "/",
                                        show_video = False, save_file_name = str(i))
        i = i + 1

# %%
#normal
i = 0
for path in NORMAL_PATH:       
    VIDEO_PATH = "videos/normal_gait/" + path

    dataframe = feature.extract_keypoint(path = VIDEO_PATH, 
                                    save_path = "dataset/Normal_gait/",
                                    show_video = False, save_file_name = str(i))
    i = i + 1

# %% [markdown]
# ### load and save dataset

# %%
FILE_PATH = os.listdir("dataset/")

# %%
gait_class = FILE_PATH

# %%
result = pd.DataFrame()

# %%
gait_class
# Out:
# ['Ataxic_Gait',
#  'Choreiform_Gait',
#  'Diplegic_Gait',
#  'Hemiplegic_Gait',
#  'Neuropathic_Gait',
#  'Normal_gait',
#  'Parkinsonian_Gait']

# %%
i = 0
for path in gait_class:       
    CSV_PATH = "dataset/" + path +"/" 
    for dataset in os.listdir(CSV_PATH):
        dataframe = pd.read_csv(CSV_PATH + dataset)
        dataframe = feature.cut_dataframe(dataframe, drop = 0.1)
        dataframe["class"] = i
        result = pd.concat([result, dataframe])
    i = i + 1

# %%
result
# Out:
#        nose_x    nose_y    nose_z  left_eye_inner_x  left_eye_inner_y  \
# 0    0.155794 -0.560939 -0.122072          0.147259         -0.604951
# 1    0.155777 -0.560795 -0.126155          0.147371         -0.604803
# 2    0.151617 -0.560695 -0.131444          0.144571         -0.604709
# 3    0.139049 -0.563633 -0.138267          0.132814         -0.607674
# 4    0.135167 -0.565018 -0.142545          0.129681         -0.609012
# ..        ...       ...       ...               ...               ...
# 182 -0.303948 -0.414238  0.197718         -0.331145         -0.426748
# 183 -0.302918 -0.414219  0.199615         -0.330161         -0.426677
# 184 -0.305781 -0.410886  0.186083         -0.335011         -0.422974
# 185 -0.314547 -0.415211  0.192501         -0.344674         -0.427505
# 186 -0.315678 -0.410134  0.185404         -0.346666         -0.420954
#
#      left_eye_inner_z  left_eye_x  left_eye_y  left_eye_z  left_eye_outer_x  \
# 0           -0.109733    0.147664   -0.605619   -0.108906          0.147330
# 1           -0.113815    0.147777   -0.605468   -0.112948          0.147425
# 2           -0.118378    0.144945   -0.605367   -0.117465          0.144515
# 3           -0.123936    0.133112   -0.608260   -0.122977          0.132613
# 4           -0.128080    0.129943   -0.609575   -0.127106          0.129434
# ..                ...         ...         ...         ...               ...
# 182          0.172025   -0.331310   -0.427586    0.172297         -0.331886
# 183          0.175729   -0.330323   -0.427509    0.176011         -0.330922
# 184          0.158206   -0.335119   -0.423660    0.158468         -0.335776
# 185          0.164881   -0.344763   -0.428099    0.165119         -0.345480
# 186          0.155283   -0.346733   -0.421482    0.155456         -0.347474
#
#      ...  right_heel_x  right_heel_y  right_heel_z  left_foot_index_x  \
# 0    ...      0.314534      0.748666     -0.287023           0.539134
# 1    ...      0.314017      0.752845     -0.278537           0.538825
# 2    ...      0.289041      0.758853     -0.270650           0.570117
# 3    ...      0.260245      0.770964     -0.265184           0.593108
# 4    ...      0.245045      0.778160     -0.279495           0.591652
# ..   ...           ...           ...           ...                ...
# 182  ...      0.319274      0.683392      0.210988           0.184620
# 183  ...      0.329461      0.684800      0.213763           0.169399
# 184  ...      0.344525      0.685570      0.216250           0.169070
# 185  ...      0.353283      0.685949      0.223411           0.151379
# 186  ...      0.358687      0.686486      0.238619           0.148565
#
#      left_foot_index_y  left_foot_index_z  right_foot_index_x  \
# 0             0.699718           0.286039            0.405057
# 1             0.699970           0.290130            0.401987
# 2             0.638595           0.365999            0.368249
# 3             0.595775           0.379040            0.336879
# 4             0.608952           0.379701            0.333814
# ..                 ...                ...                 ...
# 182           0.754611          -0.030712            0.313657
# 183           0.756781          -0.011788            0.319752
# 184           0.762877           0.013510            0.330500
# 185           0.767630           0.032031            0.337335
# 186           0.769362           0.056476            0.343932
#
#      right_foot_index_y  right_foot_index_z  class
# 0              0.742862           -0.425398      0
# 1              0.749201           -0.416365      0
# 2              0.757233           -0.410194      0
# 3              0.779245           -0.401995      0
# 4              0.788730           -0.416394      0
# ..                  ...                 ...    ...
# 182            0.757752            0.206457      6
# 183            0.753015            0.211183      6
# 184            0.746879            0.214495      6
# 185            0.734868            0.227470      6
# 186            0.730374            0.243289      6
#
# [67190 rows x 100 columns]

# %% [markdown]
# * 0 : 'Ataxic_Gait'
# * 1 :  'Choreiform_Gait'
# * 2 :  'Diplegic_Gait'
# * 3 :  'Hemiplegic_Gait'
# * 4 :  'Neuropathic_Gait'
# * 5 :  'Normal_gait'
# * 6 :  'Parkinsonian_Gait'

# %%
result["class"].value_counts()
# Out:
# 6    39096
# 3    16608
# 4     5457
# 0     2234
# 2     1956
# 5      971
# 1      868
# Name: class, dtype: int64

# %%
result.to_csv("result/keypoints.csv", index = False)

# %%
result = pd.read_csv("result/keypoints.csv")

# %% [markdown]
# ### compute feature

# %%
feature_angle = feature.compute_angle_feature(path = "result/keypoints.csv", save_path = "feature/", save_file_name = "result")
feature_len = feature.compute_len_feature(path = "result/keypoints.csv", save_path = "feature/", save_file_name = "result")
feature_diff = feature.compute_diff_feature(path = "result/keypoints.csv", save_path = "feature/", save_file_name = "result")

# %%
feature_result = pd.concat([feature_angle, feature_diff, feature_len], axis = 1)

# %%
feature_result["class"] = result["class"]

# %%
feature_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67190 entries, 0 to 67189
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   left_hip_anlge        67190 non-null  float64
#  1   right_hip_anlge       67190 non-null  float64
#  2   left_knee_anlge       67190 non-null  float64
#  3   right_knee_anlge      67190 non-null  float64
#  4   left_ankle_angle_1    67190 non-null  float64
#  5   left_ankle_angle_2    67190 non-null  float64
#  6   right_ankle_angle_1   67190 non-null  float64
#  7   right_ankle_angle_2   67190 non-null  float64
#  8   hip_x_diff            67190 non-null  float64
#  9   hip_y_diff            67190 non-null  float64
#  10  hip_depth_diff        67190 non-null  float64
#  11  knee_x_diff           67190 non-null  float64
#  12  knee_y_diff           67190 non-null  float64
#  13  knee_depth_diff       67190 non-null  float64
#  14  ankle_x_diff          67190 non-null  float64
#  15  ankle_y_diff          67190 non-null  float64
#  16  ankle_depth_diff      67190 non-null  float64
#  17  heel_x_diff           67190 non-null  float64
#  18  heel_y_diff           67190 non-null  float64
#  19  heel_depth_diff       67190 non-null  float64
#  20  footindex_x_diff      67190 non-null  float64
#  21  footindex_y_diff      67190 non-null  float64
#  22  footindex_depth_diff  67190 non-null  float64
#  23  hip_length            67190 non-null  float64
#  24  knee_length           67190 non-null  float64
#  25  ankle_length          67190 non-null  float64
#  26  heel_length           67190 non-null  float64
#  27  footindex_length      67190 non-null  float64
#  28  class                 67190 non-null  int64
# dtypes: float64(28), int64(1)
# memory usage: 14.9 MB

# %%
feature_result.to_csv("result/features.csv", index = False)

# %% [markdown]
# ### EDA

# %%
#for eda
feature_angle = feature.compute_angle_feature(path = "result/keypoints.csv", save_path = "feature/", save_file_name = "result")
feature_angle["class"] = result["class"]
feature_len = feature.compute_len_feature(path = "result/keypoints.csv", save_path = "feature/", save_file_name = "result")
feature_len["class"] = result["class"]
feature_diff = feature.compute_diff_feature(path = "result/keypoints.csv", save_path = "feature/", save_file_name = "result")
feature_diff["class"] = result["class"]

# %% [markdown]
# ### EDA angle

# %% [markdown]
# ### EDA diff

# %%
feature_diff[feature_diff["class"] == 0]
# Out:
#       hip_x_diff  hip_y_diff  hip_depth_diff  knee_x_diff  knee_y_diff  \
# 0      -0.154935    0.039753       -0.187853    -0.111677     0.071158
# 1      -0.157103    0.040176       -0.188175    -0.115101     0.067958
# 2      -0.160072    0.041390       -0.188153    -0.123984     0.077713
# 3      -0.164717    0.043902       -0.185067    -0.139595     0.077759
# 4      -0.165472    0.045260       -0.184912    -0.149083     0.079157
# ...          ...         ...             ...          ...          ...
# 2229   -0.132150   -0.030300       -0.183020    -0.014240    -0.005715
# 2230   -0.131894   -0.031803       -0.181796    -0.018558    -0.006482
# 2231   -0.129825   -0.032398       -0.180998    -0.024378    -0.009751
# 2232   -0.131412   -0.037991       -0.173831    -0.035416    -0.015369
# 2233   -0.134432   -0.040011       -0.170204    -0.050651    -0.017001
#
#       knee_depth_diff  ankle_x_diff  ankle_y_diff  ankle_depth_diff  \
# 0           -0.402590     -0.086559      0.078057         -0.602044
# 1           -0.397028     -0.086893      0.081261         -0.599091
# 2           -0.419861     -0.138003      0.130128         -0.652983
# 3           -0.415213     -0.186813      0.168882         -0.656137
# 4           -0.413721     -0.197246      0.165621         -0.668280
# ...               ...           ...           ...               ...
# 2229        -0.220542      0.166065      0.129960         -0.306115
# 2230        -0.166321      0.086359      0.063038         -0.170135
# 2231        -0.151856      0.016928      0.019535         -0.156305
# 2232        -0.123684      0.006891      0.004166         -0.106930
# 2233        -0.119792     -0.013273      0.001024         -0.101096
#
#       heel_x_diff  heel_y_diff  heel_depth_diff  footindex_x_diff  \
# 0       -0.094615     0.075750        -0.623382         -0.134077
# 1       -0.094910     0.079507        -0.620717         -0.136838
# 2       -0.153209     0.133088        -0.679714         -0.201867
# 3       -0.205850     0.177334        -0.684294         -0.256229
# 4       -0.214847     0.172534        -0.697298         -0.257838
# ...           ...          ...              ...               ...
# 2229     0.179026     0.139685        -0.310516          0.213917
# 2230     0.086252     0.063556        -0.168742          0.068208
# 2231     0.007814     0.016539        -0.155730         -0.018122
# 2232     0.000511     0.001505        -0.104209         -0.018458
# 2233    -0.019264    -0.001348        -0.098684         -0.046171
#
#       footindex_y_diff  footindex_depth_diff  class
# 0             0.043144             -0.711437      0
# 1             0.049231             -0.706496      0
# 2             0.118639             -0.776193      0
# 3             0.183470             -0.781036      0
# 4             0.179778             -0.796095      0
# ...                ...                   ...    ...
# 2229          0.079075             -0.376227      0
# 2230          0.023894             -0.206352      0
# 2231         -0.005480             -0.190274      0
# 2232         -0.017141             -0.125300      0
# 2233         -0.019076             -0.123604      0
#
# [2234 rows x 16 columns]

# %%
col_list = list(feature_diff.columns)
feature_name = ["hip", "knee", "ankle", "heel", "foot"]

for gait in range(len(gait_class)):
    feature_diff_by_class = feature_diff[feature_diff["class"] == gait]
    plt.figure(figsize = (20,20))
    plt.title(gait_class[gait])
    for i in range(int(len(col_list) / 3)):
        plt.scatter(x = feature_diff_by_class[col_list[i]], y=feature_diff_by_class[col_list[i+1]], label = feature_name[i])
    plt.legend()
    plt.show()

# %% [markdown]
# ## ML and KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

# %%
dataset = feature_result

# %%
dataset
# Out:
#        left_hip_anlge  right_hip_anlge  left_knee_anlge  right_knee_anlge  \
# 0          148.427729       150.930978      -168.393137       -168.690248
# 1          149.004593       151.639707      -168.831517       -169.054899
# 2          149.866687       154.455256      -176.729935       -169.385073
# 3          151.410257       157.807758       176.079346       -169.617673
# 4          151.174823       158.637350       178.446366       -169.004416
# ...               ...              ...              ...               ...
# 67185     -157.427835      -174.382649       156.083147        165.318717
# 67186     -157.320103      -175.574536       158.249472        165.948759
# 67187     -157.362197      -176.931101       159.634896        168.342233
# 67188     -157.326966      -178.706697       161.841175        170.602864
# 67189     -156.925723      -179.500483       162.787619        172.070385
#
#        left_ankle_angle_1  left_ankle_angle_2  right_ankle_angle_1  \
# 0              134.300391          134.300391           131.807541
# 1              134.225455          134.225455           133.502207
# 2              135.144423          135.144423           134.610390
# 3              136.121906          136.121906           138.617568
# 4              134.825773          134.825773           135.521153
# ...                   ...                 ...                  ...
# 67185         -153.313693         -153.313693          -157.421886
# 67186         -150.804218         -150.804218          -154.879116
# 67187         -151.106661         -151.106661          -152.636233
# 67188         -143.695643         -143.695643          -151.358310
# 67189         -145.530537         -145.530537          -152.758030
#
#        right_ankle_angle_2  hip_x_diff  hip_y_diff  ...  heel_depth_diff  \
# 0               178.505128   -0.154935    0.039753  ...        -0.623382
# 1               178.704709   -0.157103    0.040176  ...        -0.620717
# 2               177.797498   -0.160072    0.041390  ...        -0.679714
# 3               176.920373   -0.164717    0.043902  ...        -0.684294
# 4               175.881984   -0.165472    0.045260  ...        -0.697298
# ...                    ...         ...         ...  ...              ...
# 67185          -175.595635    0.120291   -0.024033  ...         0.243925
# 67186          -174.416427    0.121045   -0.023037  ...         0.227674
# 67187          -174.214714    0.120728   -0.024073  ...         0.204691
# 67188          -173.107756    0.120841   -0.024434  ...         0.194053
# 67189          -173.724952    0.121072   -0.026504  ...         0.186554
#
#        footindex_x_diff  footindex_y_diff  footindex_depth_diff  hip_length  \
# 0             -0.134077          0.043144             -0.711437    0.159954
# 1             -0.136838          0.049231             -0.706496    0.162159
# 2             -0.201867          0.118639             -0.776193    0.165336
# 3             -0.256229          0.183470             -0.781036    0.170467
# 4             -0.257838          0.179778             -0.796095    0.171550
# ...                 ...               ...                   ...         ...
# 67185          0.129037          0.003140              0.237169    0.122668
# 67186          0.150352         -0.003766              0.222971    0.123218
# 67187          0.161430         -0.015999              0.200984    0.123104
# 67188          0.185956         -0.032761              0.195439    0.123286
# 67189          0.195367         -0.038988              0.186813    0.123939
#
#        knee_length  ankle_length  heel_length  footindex_length  class
# 0         0.132421      0.116557     0.121203          0.140848      0
# 1         0.133666      0.118970     0.123811          0.145425      0
# 2         0.146326      0.189679     0.202942          0.234148      0
# 3         0.159791      0.251833     0.271701          0.315142      0
# 4         0.168795      0.257558     0.275549          0.314325      0
# ...            ...           ...          ...               ...    ...
# 67185     0.150849      0.129777     0.118559          0.129075      6
# 67186     0.157620      0.148503     0.137475          0.150400      6
# 67187     0.170611      0.164606     0.153301          0.162221      6
# 67188     0.181493      0.182589     0.172254          0.188819      6
# 67189     0.189083      0.193326     0.183111          0.199219      6
#
# [67190 rows x 29 columns]

# %%
#X = (dataset.iloc[:, :-1] - dataset.iloc[:, :-1].mean()) / dataset.iloc[:, :-1].std()

# %%
X = dataset.iloc[:, :-1].to_numpy()

# %%
Y = dataset.iloc[:, 28].to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
print(len(X_train), len(X_test))
print(X_train[:3])
print(y_train[:3])
# Out:
# 53752 13438
# [[ 1.38967094e+02  1.28201677e+02 -1.69885153e+02 -1.63269859e+02
#    1.18487314e+02  1.18487314e+02  1.14205336e+02  1.74027687e+02
#   -5.97205828e-03  2.55586940e-03 -2.37272717e-01  5.64154908e-02
#    2.10415125e-02 -2.38983449e-01  6.72233924e-02  2.86179781e-02
#   -2.67897108e-01  6.29280843e-02  2.48066783e-02 -2.70163376e-01
#    5.97663522e-02  5.50723076e-03 -3.12189799e-01  6.49599480e-03
#    6.02117335e-02  7.30614341e-02  6.76410754e-02  6.00195505e-02]
#  [-1.53677844e+02 -1.48352846e+02  1.67126269e+02  1.43023246e+02
#   -1.32748740e+02 -1.32748740e+02 -1.13084408e+02 -1.61826731e+02
#   -8.66848454e-02  6.40660524e-03  1.81217358e-01 -1.29223982e-01
#   -1.40300393e-02  1.42487105e-01 -1.16378281e-02  2.16177702e-02
#    8.91094934e-02 -1.06559237e-02  2.68535018e-02  8.53401944e-02
#   -3.39694023e-02  3.49292755e-02  1.00985527e-01  8.69212690e-02
#    1.29983382e-01  2.45513142e-02  2.88904702e-02  4.87234500e-02]
#  [-1.19601858e+02 -1.26909670e+02  1.55513270e+02  1.63504816e+02
#   -9.97302858e+01 -9.97302858e+01 -1.11666392e+02 -1.66907979e+02
#   -5.90753462e-03  1.08754751e-03  2.06140488e-01  1.52656436e-02
#   -2.98186541e-02  2.10114568e-01 -1.74980462e-02 -3.55895162e-02
#    2.32155064e-01 -2.78698131e-02 -2.70926356e-02  2.35834913e-01
#   -2.19538212e-02 -1.01352334e-02  2.61737902e-01  6.00680655e-03
#    3.34991344e-02  3.96584831e-02  3.88682054e-02  2.41804305e-02]]
# [6 3 6]

# %%
scaler = StandardScaler() # Scaler 객체 생성
scaler.fit(X_train) # 스케일링(표준화)를 위한 평균과 표준 편차 계산
X_train = scaler.transform(X_train) # 스케일링(표준화 수행)
X_test = scaler.transform(X_test)

# %%
for col in range(4):
    print(f'평균 = {X_train[:, col].mean()}, 표준편차= {X_train[:, col].std()}')
for col in range(4):
    print(f'평균 = {X_test[:, col].mean()}, 표준편차= {X_test[:, col].std()}')
# Out:
# 평균 = 6.332517814516223e-16, 표준편차= 1.000000000000002
# 평균 = -1.1077444793997693e-16, 표준편차= 1.0000000000000002
# 평균 = -2.351181048072076e-15, 표준편차= 1.0000000000000009
# 평균 = 2.909481621907986e-16, 표준편차= 1.000000000000001
# 평균 = -0.0074715061367412305, 표준편차= 0.9983982034256557
# 평균 = -0.002601028922609754, 표준편차= 0.9998340272620577
# 평균 = 0.012159283999208135, 표준편차= 0.9955496907098477
# 평균 = 0.020738851305916146, 표준편차= 1.0001860065299721

# %%
# k-NN 분류기를 생성
classifier = KNeighborsClassifier(n_neighbors=5)
# 분류기 학습
classifier.fit(X_train, y_train)
# 예측
y_pred = classifier.predict(X_test)
print(y_pred)
# 5. 모델 평가
conf_matrix = confusion_matrix(y_test, y_pred)
print(conf_matrix)
print(classification_report(y_test, y_pred))
report = classification_report(y_test, y_pred, output_dict=True)
# Out:
# [6 3 4 ... 6 6 6]
# [[ 349    3    7   12   15    0   43]
#  [   7  125    5   35    9    1   17]
#  [   7    1  358    7    0    0   27]
#  [   3    5    9 3164    9    0   15]
#  [   3    4    4   37 1011    6   50]
#  [   5    1    0   13   24  144   13]
#  [   2    0    2   14   49    2 7821]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.81      0.87       429
#            1       0.90      0.63      0.74       199
#            2       0.93      0.90      0.91       400
#            3       0.96      0.99      0.98      3205
#            4       0.91      0.91      0.91      1115
#            5       0.94      0.72      0.82       200
#            6       0.98      0.99      0.99      7890
#
#     accuracy                           0.97     13438
#    macro avg       0.94      0.85      0.89     13438
# weighted avg       0.96      0.97      0.96     13438

# %%
report["accuracy"]
# Out:
# 0.965322220568537

# %%
errors = []
acc = []
for i in range(1, 31):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    errors.append(np.mean(pred_i != y_test))
    report = classification_report(y_test, y_pred, output_dict=True)
    acc.append(report["accuracy"])

#print(errors)

plt.plot(range(1, 31), errors, marker='o')
plt.title('Mean error with K-Value')
plt.xlabel('k-value')
plt.ylabel('mean error')
plt.show()

plt.plot(range(1, 31), acc, color = 'violet', marker='o')
plt.title('Acc with K-Value')
plt.xlabel('k-value')
plt.ylabel('acc')
plt.show()
